# %%
###############################################################################
#                                                                             
#  Original Code taken from:                                                  
#  https://scipy-lectures.org/advanced/mathematical_optimization/index.html                                                                                                                                                
###############################################################################

"""
Illustration of 1D optimization (Minimization): Brent's method
"""

import numpy as np
import matplotlib.pyplot as plt
from scipy import optimize

x = np.linspace(-3.5, 3.5, 1000)

# A Quadratic plus Gaussian Function
def quadgauss(x):
    return 2.0*(x**2) + 3.0*(x) + 2.0 + 5.0*np.exp(-x**2)


all_x = list()
all_y = list()
for iter in range(8):
    result = optimize.minimize_scalar(quadgauss, bracket = (-5, 2.9, 4.5), method = "Brent",
             options = {"maxiter": iter}, tol = np.finfo(1.0).eps)

    this_x = result.x
    all_x.append(this_x)
    all_y.append(quadgauss(this_x))
    if iter < 5:
       plt.text(this_x - .05*np.sign(this_x) - .05,
                quadgauss(this_x) + 1.2*(.3 - iter % 2), iter + 1, size = 8, color = 'black')
    
plt.plot(x, quadgauss(x), linewidth = 1, color = 'm', label = r'f(x) = $2x^2 + 3x + 2 + 5e^{-x^2}$')
plt.ylabel(r'f(x) = $2x^2 + 3x + 2 + 5e^{-x^2}$')
plt.xlabel('x')
plt.title("Minimization of f(x) using Brent's Method")    
plt.plot(all_x[:10], all_y[:10], 'k.', markersize = 5, color = 'r', label = 'Iteration Points')
plt.plot(all_x[-1], all_y[-1], 'rx', markersize = 8, color = 'b', label = 'Minimum Point')
plt.grid(color='c', alpha = 0.7, linestyle='dotted', linewidth = 0.5)
plt.legend()
plt.savefig('Function_minimization_Brent.pdf')
# Out:
# C:\Users\a828a124\AppData\Local\Temp\ipykernel_360\541093197.py:39: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k." (-> color='k'). The keyword argument will take precedence.
#   plt.plot(all_x[:10], all_y[:10], 'k.', markersize = 5, color = 'r', label = 'Iteration Points')
# C:\Users\a828a124\AppData\Local\Temp\ipykernel_360\541093197.py:40: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "rx" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(all_x[-1], all_y[-1], 'rx', markersize = 8, color = 'b', label = 'Minimum Point')
